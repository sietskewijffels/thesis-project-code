# %%
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

file_path = 'merged_participant_data.json'

with open(file_path, 'r') as file:
    data = json.load(file)


# Now you can work with the un-JSONed data
# For example, you can access specific values using keys
# print(data)

# %% [markdown]
# ### Create long dataframe|

# %% [markdown]
# Meeting met Martijn:
# Maak een lang dataframe en probeer 'is_detected' te voorspellen met een multilevel regression
# Voeg verschillende variabelen toe:
# - type patroon
# - volgorde van version
# - volgorde van dataset
# - leereffect centreren door van -17 tot + 17 te laten gaan

# %%
new_data = data['participants'][0]

# %%
dataset_map = { 'dataset1': {0:'short', 1:'long', 2:'change', 3:'short', 4:'long', 5:'change', 
                            6:'short', 7:'change', 8:'change', 9:'long', 10:'short', 11:'long'}, 
                'dataset2': {0:'long', 1:'change', 2:'change', 3:'short', 4:'change', 5:'short',
                            6:'long', 7:'long', 8:'long', 9:'short', 10:'change', 11:'short'},
                'dataset3': {0:'change', 1:'change', 2:'long', 3:'long', 4:'long', 5:'short',
                            6:'short', 7:'short', 8:'change', 9:'change', 10:'short', 11:'long'},
                'dataset4': {0:'short', 1:'short', 2:'long', 3:'long', 4:'short', 5:'short',
                            6:'long', 7:'change', 8:'long', 9:'change', 10:'change', 11:'change'}
               }

# %%
new_data['metadata']['version_sequence'][0]
# Out:
# 'version3'

# %%
def preprocessing(log_version, data):
  log_version_data = data[log_version]

  # Flatten the nested lists
  flattened_data = [item for sublist in log_version_data for item in sublist]

  df = pd.json_normalize(flattened_data)
  df.rename(columns={'block.id': 'id'}, inplace=True)
  df.rename(columns={'block.xpos': 'xpos'}, inplace=True)
  df.rename(columns={'block.colorID': 'colorID'}, inplace=True)
  df.rename(columns={'block.eventCat': 'eventCat'}, inplace=True)
  df.rename(columns={'block.inititialTime': 'inititialTime'}, inplace=True)
  df.rename(columns={'block.detectionTime': 'detectionTime'}, inplace=True)

  # Assuming 'df' is your dataframe
  df['inititialTime'] = pd.to_datetime(df['inititialTime'])
  df['detectionTime'] = pd.to_datetime(df['detectionTime'])

  # Now you can compute the reaction time as the difference
  df['reactionTime'] = df['detectionTime'] - df['inititialTime']

  # To convert the reaction time from a timedelta to a more usable format (e.g., seconds)
  df['reactionTime_seconds'] = df['reactionTime'].dt.total_seconds()

  #remove the rows where sequenceID is NaN
  df = df.dropna(subset=['sequenceID'])

  return df

# %%
df = preprocessing('log_version3', new_data)

# %%
# returns a dataframe with all last clicks of the participant

def last_click_to_df(df):

  marked_an_unmarked_clicks = df[(df['source'] == 'user') & ((df['event'] == 'confirmAnomaly') | (df['event'] == 'unmarkAnomaly') | (df['event'] == 'markAsAnomaly'))]
  marked_an_unmarked_clicks = marked_an_unmarked_clicks.sort_values(by =['sequenceID','id','detectionTime'])	

  # i want to remove the rows of drop_duplicates from the marked_an_unmarked_clicks
  no_duplicated_clicks = marked_an_unmarked_clicks.drop_duplicates(subset=['sequenceID', 'id'], keep='last')

  return no_duplicated_clicks

# %%
def anomalies_to_df(df):
  anomalies = df[df['event'] == 'anomaly']
  anomalies = anomalies[['sequenceID', 'id', 'eventCat']]
  sorted_anomalies = anomalies.sort_values(by=['sequenceID', 'id'])
  sorted_anomalies.reset_index(drop=True, inplace=True)

  return sorted_anomalies

# %%
def long_dataframe(last_click, anomalies, detector):

  # unmarked clicks eruit gehaald
  last_click_archive = last_click.copy()

  last_click = last_click[last_click['event'] != 'unmarkAnomaly']
  last_click = last_click[['sequenceID', 'id']]
  last_click.reset_index(drop=True, inplace=True)

  # anomaly frame
  anomalies['is_detected'] = anomalies.apply(lambda row: (row['sequenceID'], row['id']) in zip(last_click['sequenceID'], last_click['id']), axis=1)
  
  #i want to merge the column 'reactionTime_seconds' of last_click_archive with the anomalies df while keeping all rows of anomalies
  anoamlies_reaction_time_df = anomalies.merge(last_click_archive, on=['sequenceID', 'id'], how='left')
  anoamlies_reaction_time_df = anoamlies_reaction_time_df[['sequenceID', 'id', 'eventCat_x', 'is_detected', 'reactionTime_seconds']]
  anoamlies_reaction_time_df.rename(columns={'eventCat_x': 'eventCat'}, inplace=True)

  anoamlies_reaction_time_df['automatic_detection'] = anoamlies_reaction_time_df.apply(lambda row: (row['sequenceID'], row['id']) in zip(detector['sequenceID'], detector['id']), axis=1)

  return anoamlies_reaction_time_df

# %%
def events_detector(df_test):
  df_anomaly_detector = df_test[df_test['source'] == 'detector']
  df_anomaly_detector = df_anomaly_detector[['sequenceID', 'id']]
  df_anomaly_detector.sort_values(by=['sequenceID', 'id'], inplace=True)

  return df_anomaly_detector

# %%
long_frame = long_dataframe(last_click_to_df(df), anomalies_to_df(df), events_detector(df))

# %%
long_frame['version'] = new_data['metadata']['version_sequence'][0]

# %%
def df_per_version(version, participant_data):

  df = preprocessing(version, participant_data)
  long_frame = long_dataframe(last_click_to_df(df), anomalies_to_df(df), events_detector(df))

  #version data
  long_frame['version'] = participant_data['metadata']['version_sequence'][int(version[-1])-1]
  long_frame['run_order'] = int(version[-1])
  long_frame['dataset'] = participant_data['metadata']['dataset_sequence'][int(version[-1])-1]

  #pattern data
  def get_pattern(row):
      dataset = row['dataset']
      sequenceID = row['sequenceID']
      return dataset_map.get(dataset, {}).get(sequenceID, None)
    
  long_frame['pattern'] = long_frame.apply(get_pattern, axis=1)

  #participant data
  long_frame['participant'] = participant_data['metadata']['participant_number']
  long_frame['gender'] = participant_data['metadata']['gender']
  long_frame['age'] = participant_data['metadata']['age']
  long_frame['education'] = participant_data['metadata']['education']
  long_frame['experience'] = participant_data['metadata']['experience']

  #survey data
  long_frame['general_difficulty'] = participant_data['survey']['anomaly_difficulty']
  long_frame['automatic_detection_helpful'] = participant_data['survey'].get('automatic_detection_helpful', pd.NA)
  long_frame['history_helpful'] = participant_data['survey']['history_helpful']
  long_frame['difficult_v1'] = participant_data['survey']['difficult_v1']
  long_frame['difficult_v2'] = participant_data['survey']['difficult_v2']
  long_frame['difficult_v3'] = participant_data['survey']['difficult_v3']
  long_frame['difficult_v4'] = participant_data['survey']['difficult_v4']
  long_frame['preference_v1'] = participant_data['survey']['preference_v1']
  long_frame['preference_v2'] = participant_data['survey']['preference_v2']
  long_frame['preference_v3'] = participant_data['survey']['preference_v3']
  long_frame['preference_v4'] = participant_data['survey']['preference_v4']

  # Reset the index to create the 'anomalyID' column and rename it
  long_frame.reset_index(inplace=True)
  long_frame.rename(columns={'index': 'anomalyID'}, inplace=True)

  # Reorder the columns, making 'participant' the first column after the index
  columns = ['participant'] + [col for col in long_frame.columns if col != 'participant']
  long_frame = long_frame[columns]

  version_mapping = {
    'version1': 'window',
    'version2': 'history',
    'version3': 'window+ad',
    'version4': 'history+ad'
  }
    
  # Replace the values in the 'version' column
  long_frame['version'] = long_frame['version'].replace(version_mapping)
  
  return long_frame

# %%
def df_per_participant(participant_data):
  df = pd.DataFrame()

  for i in range(1, 5):
    df = df.append(df_per_version(f'log_version{i}', participant_data))

  return df

# %%
checken = df_per_participant(new_data)
checken
# Out:
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
#    participant  anomalyID  sequenceID     id eventCat  is_detected  \
# 0           18          0         0.0   82.0       10        False
# 1           18          1         0.0  143.0       10         True
# 2           18          2         0.0  179.0       10         True
# 3           18          3         0.0  212.0       10         True
# 4           18          4         1.0   63.0       10         True
# ..         ...        ...         ...    ...      ...          ...
# 31          18         31         9.0  202.0       10         True
# 32          18         32        11.0   69.0       10         True
# 33          18         33        11.0  118.0       10         True
# 34          18         34        11.0  173.0        9         True
# 35          18         35        11.0  219.0       10         True
#
#     reactionTime_seconds  automatic_detection    version  run_order  ...  \
# 0                    NaN                False  window+ad          1  ...
# 1                  4.318                False  window+ad          1  ...
# 2                 19.697                False  window+ad          1  ...
# 3                 22.615                False  window+ad          1  ...
# 4                 19.983                False  window+ad          1  ...
# ..                   ...                  ...        ...        ...  ...
# 31                 6.862                 True     window          4  ...
# 32                10.697                False     window          4  ...
# 33                18.525                 True     window          4  ...
# 34                 7.613                 True     window          4  ...
# 35                10.302                 True     window          4  ...
#
#    automatic_detection_helpful history_helpful difficult_v1 difficult_v2  \
# 0                            6               1            3            4
# 1                            6               1            3            4
# 2                            6               1            3            4
# 3                            6               1            3            4
# 4                            6               1            3            4
# ..                         ...             ...          ...          ...
# 31                           6               1            3            4
# 32                           6               1            3            4
# 33                           6               1            3            4
# 34                           6               1            3            4
# 35                           6               1            3            4
#
#    difficult_v3 difficult_v4 preference_v1 preference_v2 preference_v3  \
# 0             1            2             4             1             3
# 1             1            2             4             1             3
# 2             1            2             4             1             3
# 3             1            2             4             1             3
# 4             1            2             4             1             3
# ..          ...          ...           ...           ...           ...
# 31            1            2             4             1             3
# 32            1            2             4             1             3
# 33            1            2             4             1             3
# 34            1            2             4             1             3
# 35            1            2             4             1             3
#
#    preference_v4
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2
# ..           ...
# 31             2
# 32             2
# 33             2
# 34             2
# 35             2
#
# [144 rows x 27 columns]

# %%
def make_ultra_long_dataframe(data):
  df = pd.DataFrame()

  for participant in data['participants']:
    df = df.append(df_per_participant(participant))

  return df

# %%
complete_df = make_ultra_long_dataframe(data)
complete_df

#complete_df.to_csv('complete_df.csv', index=False) dit niet meer gebruiken
# Out:
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# ...
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1949130505.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_version(f'log_version{i}', participant_data))
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\82302009.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_per_participant(participant))
#    participant  anomalyID  sequenceID     id eventCat  is_detected  \
# 0           18          0         0.0   82.0       10        False
# 1           18          1         0.0  143.0       10         True
# 2           18          2         0.0  179.0       10         True
# 3           18          3         0.0  212.0       10         True
# 4           18          4         1.0   63.0       10         True
# ..         ...        ...         ...    ...      ...          ...
# 31           9         31         9.0  202.0       10        False
# 32           9         32        11.0   69.0       10         True
# 33           9         33        11.0  118.0       10         True
# 34           9         34        11.0  173.0        9         True
# 35           9         35        11.0  219.0       10         True
#
#     reactionTime_seconds  automatic_detection     version  run_order  ...  \
# 0                    NaN                False   window+ad          1  ...
# 1                  4.318                False   window+ad          1  ...
# 2                 19.697                False   window+ad          1  ...
# 3                 22.615                False   window+ad          1  ...
# 4                 19.983                False   window+ad          1  ...
# ..                   ...                  ...         ...        ...  ...
# 31                   NaN                False  history+ad          4  ...
# 32                26.727                False  history+ad          4  ...
# 33                18.463                 True  history+ad          4  ...
# 34                11.100                 True  history+ad          4  ...
# 35                22.010                 True  history+ad          4  ...
#
#    automatic_detection_helpful history_helpful difficult_v1 difficult_v2  \
# 0                            6               1            3            4
# 1                            6               1            3            4
# 2                            6               1            3            4
# 3                            6               1            3            4
# 4                            6               1            3            4
# ..                         ...             ...          ...          ...
# 31                           5               2            4            3
# 32                           5               2            4            3
# 33                           5               2            4            3
# 34                           5               2            4            3
# 35                           5               2            4            3
#
#    difficult_v3 difficult_v4 preference_v1 preference_v2 preference_v3  \
# 0             1            2             4             1             3
# 1             1            2             4             1             3
# 2             1            2             4             1             3
# 3             1            2             4             1             3
# 4             1            2             4             1             3
# ..          ...          ...           ...           ...           ...
# 31            2            1             1             2             3
# 32            2            1             1             2             3
# 33            2            1             1             2             3
# 34            2            1             1             2             3
# 35            2            1             1             2             3
#
#    preference_v4
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2
# ..           ...
# 31             4
# 32             4
# 33             4
# 34             4
# 35             4
#
# [7632 rows x 27 columns]

# %%
complete_df['participant'] = complete_df['participant'].astype(int)
complete_df['version'] = complete_df['version'].astype(str)

# %%
all_metrics = pd.read_csv('all_metrics.csv')

all_metrics
# Out:
#      participant     version  recall  precision    F1  TP  FN  FP
# 0             18      window    0.86       0.46  0.60  31   5  37
# 1             43      window    0.72       0.39  0.51  26  10  40
# 2             51      window    0.58       1.00  0.74  21  15   0
# 3             42      window    0.72       0.38  0.49  26  10  43
# 4             12      window    0.72       0.68  0.70  26  10  12
# ..           ...         ...     ...        ...   ...  ..  ..  ..
# 207           64  history+ad    0.58       0.84  0.69  21  15   4
# 208           66  history+ad    0.69       0.73  0.71  25  11   9
# 209           14  history+ad    0.31       0.50  0.38  11  25  11
# 210           73  history+ad    0.72       0.48  0.58  26  10  28
# 211            9  history+ad    0.67       0.75  0.71  24  12   8
#
# [212 rows x 8 columns]

# %%
all_metrics['participant'] = all_metrics['participant'].astype(int)
all_metrics['version'] = all_metrics['version'].astype(str)

# %%
df_merged = pd.merge(complete_df, all_metrics, on=['participant', 'version'], how='left')
df_merged

#remove the rows with participant number 11 and 42
df_merged = df_merged[df_merged['participant'] != 11]
df_merged = df_merged[df_merged['participant'] != 42]

df_merged

df_merged.to_csv('complete_df_recall.csv', index=False)

# %%
def search_survey(data):
  df = pd.DataFrame()

  for participant in data['participants']:  
      # Create a copy of the survey dictionary and add the participant number
      survey_data = participant['survey'].copy()
      survey_data['participant'] = participant['metadata']['participant_number']
      
      # Append the updated survey data to the dataframe
      df = df.append(survey_data, ignore_index=True)

  return df

# %%
survey_results = search_survey(data)
survey_results

# survey_results.to_csv('survey_results.csv', index=False)
# Out:
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
# C:\Users\s152296\AppData\Local\Temp\ipykernel_24324\1939788867.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(survey_data, ignore_index=True)
#    anomaly_difficulty automatic_detection_helpful  \
# 0                   2                           6
# 1                   2                           5
# 2                   2                           3
# 3                   2                           6
# 4                   2                           5
# 5                   2                           5
# 6                   2                           2
# 7                   3                           3
# 8                   2                           1
# 9                   2                           5
# 10                  2                           5
# 11                  2                           5
# 12                  1                           3
# 13                  2                           2
# 14                  2                           2
# 15                  2                           5
# 16                  2                           5
# 17                  2                           5
# 18                  2                           2
# 19                  2                           5
# 20                  2                           6
# 21                  2                           7
# 22                  2                           6
# 23                  2                           6
# 24                  2                           6
# 25                  2                           6
# 26                  3                           5
# 27                  2                           4
# 28                  2                           5
# 29                  2                           6
# 30                  2                           7
# 31                  1                           5
# 32                  1                           5
# 33                  2                           5
# 34                  4                           3
# 35                  1                           4
# 36                  2                           5
# 37                  2                           6
# 38                  2                         NaN
# 39                  2                           2
# 40                  2                           5
# 41                  2                           6
# 42                  1                           4
# 43                  2                           5
# 44                  2                           4
# 45                  2                           4
# 46                  2                           6
# 47                  2                           7
# 48                  2                           1
# 49                  2                           5
# 50                  2                           3
# 51                  2                           6
# 52                  1                           5
#
#               automatic_detection_helpful_explanation history_helpful  \
# 0   Especially in the runs where the blobs ´crunch...               1
# 1   Although it was incorrect quite often, it did ...               2
# 2   It was not that helpful because you still had ...               4
# 3   `Guides the eye, gives something to focus on a...               3
# 4   It gave me something to focus on, a starting p...               6
# 5   often the detection would indicate a wrong ano...               5
# 6   The automatic detection borders distracted me ...               6
# 7   Sometimes they were inaccurate so you had to w...               5
# 8   It felt like it was consistently taking starts...               6
# 9   Yes the red borders were somewhat helpful. It'...               7
# 10  In some cases it was not correct, and then you...               2
# 11  I think what was marked draw my attention, whi...               7
# 12  I ended up mainly checking the automatically d...               2
# 13  It took away my overview, because an extra ele...               4
# 14  I felt like the algorithm made errors frequent...               5
# 15        It took me a while to get used to the gaps.               6
# 16  Gives you better focus point to find the anoma...               7
# 17  A pattern change was not well recognized by th...               4
# 18  I have to look everywhere anyway and I sometim...               6
# 19  I help getting my attention but I also had to ...               4
# 20  It did guide me towards blocks that could be w...               4
# 21  It's quite a lot of data to analyze. Sometimes...               5
# 22  I felt like I was missing it when the automati...               5
# 23  I made you do a double take. Often there was a...               4
# 24  It gave some guidance but was inaccurate upon ...               2
# 25  It could count the length of larger sequences,...               6
# 26                             It draws my attention.               7
# 27  I felt like I got distracted by the red border...               3
# 28  At first, I had a bit of a hard time adapting ...               1
# 29         they are useful in focusing your attention               7
# 30                             It helps a lot I think               3
# 31                                               None               3
# 32                                               None               3
# 33                                               None               5
# 34  It confused me sometimes by giving me more to ...               3
# 35  Sometimes it highlighted an anomality I missed...               5
# 36  The automatic detection focuses your vision al...               2
# 37  especially helpful to check those, but maybe h...               6
# 38  It helped, but I'm not confident to what exten...               7
# 39  Since they are not always correct, and you hav...               2
# 40  It helped pick out some anomalies, but I feel ...               7
# 41  Some where not correct (where indicated but wh...               6
# 42  My attention was solely on the highlighted blo...               4
# 43  It did help me with finding anomalies which I ...               6
# 44  to me it seemed that the automatic detection o...               5
# 45  It seemed to give many false positives when th...               2
# 46  I feel my eyes cannot easily trace multiple mo...               5
# 47  it at least gave a focus point, since there is...               6
# 48  Without the algo, there are no red borders. An...               3
# 49  With the red blocks you had to focus on two th...               6
# 50  I first had to figure out why the red borders ...               6
# 51  It gave me a an idea what to look for which wa...               7
# 52  they highlight ones that could potentially be ...               2
#
#                           history_helpful_explanation difficult_v1  \
# 0             It did not help me deduce the patterns.            3
# 1                                                None            3
# 2                                                   -            4
# 3   Distracting and first, but data accumulated sh...            4
# 4   I found the smaller colored lines without the ...            1
# 5   the compressed view could be handy, the histor...            3
# 6   For the long chains it was easier to see the d...            2
# 7   The first time it was confusing but the last t...            4
# 8   The aggregated view did very little for me, th...            3
# 9   I particularly liked the compressed view. It h...            1
# 10                        I did not look at it at all            1
# 11  It was easier to see what the streams should b...            1
# 12  It helped in determining if a specific color s...            1
# 13  It was a bit easier to remember what pattern w...            4
# 14  Detecting short patterns was easier in this vi...            3
# 15  The compression made it easier to oversee a lo...            3
# 16                       Patterns were easier spotted            1
# 17  The long patterns were hard to spot if there w...            3
# 18  the compressed view did as patterns are more c...            2
# 19                             Only a couple of times            4
# 20  I'm not sure, both with and without history fe...            1
# 21  I did not always look at the history since I w...            1
# 22  I used it to check the pattern again. Sometime...            1
# 23  it helped with seeing the distance within de s...            2
# 24      It was too much to focus on at the same time,            3
# 25          It gave a reference to the past sequences            1
# 26  It's very helpful, since I was able to look ba...            1
# 27  It feels like it gives you more overview, beca...            4
# 28  Honestly, I didn't had a look at the history, ...            4
# 29                 makes it easier to see the pattern            1
# 30                                               None            3
# 31                                               None            2
# 32                                               None            1
# 33                                               None            3
# 34  It was nice at the start to see patterns were,...            3
# 35  The different perspectives were helpful, but b...            1
# 36                                          Too small            3
# 37  I sometimes forgot the pattern, this function ...            1
# 38  Loved the compressed view! Super helpful, 10/1...            1
# 39  I didn't really look at the aggregated and com...            4
# 40  In the compressed view it was much easier to s...            1
# 41  The longer term anomalies were better visible ...            1
# 42  It helped with the shorter patterns as these b...            4
# 43  If the blocks were closer to eachother, it was...            1
# 44  especially in the long patterns it seemed easi...            1
# 45  I found it harder to see if there 'odd ones ou...            3
# 46           I can know what the previous pattern is.            1
# 47  the history made it easier to spot longer sequ...            1
# 48  At the start the distributions are helpful bec...            4
# 49            It helps with remembering the sequence.            3
# 50  It created more overview because of the compre...            2
# 51  It helps to see the patterns a bit more clearl...            1
# 52  I felt distracted by it. wanting to compensate...            4
#
#    difficult_v2 difficult_v3 difficult_v4 preference_v1 preference_v2  \
# 0             4            1            2             4             1
# 1             4            1            2             2             1
# 2             3            2            1             1             2
# 3             3            1            2             2             1
# 4             2            3            4             4             3
# 5             4            2            2             3             4
# 6             1            4            3             2             4
# 7             3            2            1             1             3
# 8             1            4            2             2             4
# 9             2            3            4             4             3
# 10            4            2            3             4             2
# 11            3            2            4             4             3
# 12            2            3            4             1             2
# 13            2            3            1             1             3
# 14            3            3            3             2             4
# 15            4            1            2             2             1
# 16            2            3            4             4             3
# 17            4            1            2             3             4
# 18            1            4            3             3             4
# 19            2            1            3             3             2
# 20            3            2            4             4             2
# 21            3            2            4             1             3
# 22            4            3            2             4             2
# 23            4            1            3             4             2
# 24            4            1            2             2             1
# 25            3            2            4             4             2
# 26            2            3            4             4             3
# 27            3            1            2             1             2
# 28            2            2            1             1             2
# 29            2            3            4             4             3
# 30            4            1            2             3             4
# 31            1            4            3             2             1
# 32            3            2            4             4             2
# 33            4            1            2             2             1
# 34            4            1            2             3             4
# 35            2            3            4             1             3
# 36            4            1            2             2             1
# 37            2            3            4             1             2
# 38            2            4            3             4             3
# 39            3            2            1             4             3
# 40            2            4            3             4             3
# 41            3            2            4             1             3
# 42            2            3            1             2             3
# 43            3            2            4             3             2
# 44            3            2            4             4             3
# 45            4            1            2             2             1
# 46            3            2            4             4             2
# 47            3            2            4             4             2
# 48            2            3            1             1             3
# 49            1            4            2             3             1
# 50            1            4            3             3             4
# 51            3            2            4             4             3
# 52            3            2            1             1             2
#
#    preference_v3 preference_v4  \
# 0              3             2
# 1              4             3
# 2              3             4
# 3              4             3
# 4              2             1
# 5              1             2
# 6              1             3
# 7              2             4
# 8              1             3
# 9              2             1
# 10             3             1
# 11             2             1
# 12             3             4
# 13             2             4
# 14             1             3
# 15             4             3
# 16             2             1
# 17             1             2
# 18             1             2
# 19             4             1
# 20             3             1
# 21             2             4
# 22             3             1
# 23             3             1
# 24             4             3
# 25             3             1
# 26             2             1
# 27             4             3
# 28             2             4
# 29             2             1
# 30             1             2
# 31             4             3
# 32             3             1
# 33             4             2
# 34             1             2
# 35             2             4
# 36             4             3
# 37             3             4
# 38             1             2
# 39             2             1
# 40             1             2
# 41             2             4
# 42             1             4
# 43             4             1
# 44             1             2
# 45             4             3
# 46             3             1
# 47             3             1
# 48             2             4
# 49             4             2
# 50             1             2
# 51             2             1
# 52             3             4
#
#                               issues_or_interruptions participant
# 0   My mouse did not respond as quickly as it does...          18
# 1                                                None          43
# 2                                                  no          51
# 3   I only had automatic detection once, this was ...          42
# 4                                                 No.          12
# 5                                                None          52
# 6                                                  No          63
# 7                                               No :)          44
# 8                                 No more than usual.          32
# 9                                                 No.          27
# 10  yes, first try it did not work. Needed to re-e...          47
# 11  None \n(One small remark on the ranking, I do ...          56
# 12                                                 No          29
# 13                                               None          58
# 14                                                 No          31
# 15                                                 No          10
# 16                                                  -           4
# 17                                                No.          60
# 18                                                 No          36
# 19                                               None           7
# 20                                                 No          49
# 21                                                 no          59
# 22                                          No, none.           6
# 23                                                 No          50
# 24  Yes, during the start of the experiment the sc...          11
# 25                                                 no          33
# 26  No, I fortunately did not encounter any techni...          38
# 27                                                 No          70
# 28                                    No, good luck!!          41
# 29                                               None          53
# 30                                                 No          34
# 31                                               None          45
# 32                                               None          37
# 33  yes, my laptop ran out of battery during run 4...          35
# 34                                                 no          68
# 35  If an anomality occurs close to a transition, ...          24
# 36                                                 No          65
# 37                                                 no          39
# 38                                                No.          17
# 39                                                No.          62
# 40  During run 4 I double clicked my right mouse b...          67
# 41                                               None          20
# 42                                               None          25
# 43                                               nope           8
# 44  I don't think I did. one thing I noticed durin...          16
# 45                                               None          15
# 46                                                 no          26
# 47                                                 no          13
# 48  Some jitter in the compressed view (pixels at ...          64
# 49                                                 No          66
# 50                                                 No          14
# 51                                       No I did not          73
# 52                                               nope           9

# %% [markdown]
# Voor morgen:
# - patronen toevoegen door een mapping te maken van versie van patronen
# - quantitative data toevoegen
# - dataset en versie etc. toevoegen
